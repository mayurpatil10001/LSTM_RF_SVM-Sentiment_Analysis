# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import yfinance as yf

# Define the stock ticker symbol 
ticker_symbol = "TCS.NS"

# Define the start and end dates
start_date = "2000-01-01"
end_date = "2025-02-27"

# Fetch historical stock data using yfinance
stock_data = yf.download(ticker_symbol, start=start_date, end=end_date)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
# Save the data to a CSV file
csv_file_name = f"{ticker_symbol}_stock_data.csv"
stock_data.to_csv(csv_file_name)

# %%
# Data Loading and Preprocessing
df = pd.read_csv('TCS.NS_stock_data.csv')

# %%
df
# Out:
#            Price               Close                High                 Low  \
# 0         Ticker              TCS.NS              TCS.NS              TCS.NS
# 1           Date                 NaN                 NaN                 NaN
# 2     2002-08-12   28.11940574645996  28.331894414178297  27.428814198950363
# 3     2002-08-13  27.738685607910156  28.606351223804324  27.535051261351068
# 4     2002-08-14  25.826297760009766  27.800675890570268   25.30392621070466
# ...          ...                 ...                 ...                 ...
# 5595  2025-02-19    3784.10009765625   3874.949951171875    3768.14990234375
# 5596  2025-02-20    3779.39990234375              3788.0   3751.300048828125
# 5597  2025-02-21              3786.0              3817.0              3775.0
# 5598  2025-02-24    3675.60009765625   3763.199951171875              3670.0
# 5599  2025-02-25   3629.550048828125              3658.0             3621.25
#
#                     Open   Volume
# 0                 TCS.NS   TCS.NS
# 1                    NaN      NaN
# 2     27.428814198950363   212976
# 3     28.154811257587266   153576
# 4     27.800675890570268   822776
# ...                  ...      ...
# 5595   3872.199951171875  4366672
# 5596              3761.5  2888572
# 5597    3776.10009765625  1833931
# 5598    3743.14990234375  2508516
# 5599              3625.0  4101954
#
# [5600 rows x 6 columns]

# %%
df.head()
# Out:
#         Price               Close                High                 Low  \
# 0      Ticker              TCS.NS              TCS.NS              TCS.NS
# 1        Date                 NaN                 NaN                 NaN
# 2  2002-08-12   28.11940574645996  28.331894414178297  27.428814198950363
# 3  2002-08-13  27.738685607910156  28.606351223804324  27.535051261351068
# 4  2002-08-14  25.826297760009766  27.800675890570268   25.30392621070466
#
#                  Open  Volume
# 0              TCS.NS  TCS.NS
# 1                 NaN     NaN
# 2  27.428814198950363  212976
# 3  28.154811257587266  153576
# 4  27.800675890570268  822776

# %%
df.tail()
# Out:
#            Price              Close               High                Low  \
# 5595  2025-02-19   3784.10009765625  3874.949951171875   3768.14990234375
# 5596  2025-02-20   3779.39990234375             3788.0  3751.300048828125
# 5597  2025-02-21             3786.0             3817.0             3775.0
# 5598  2025-02-24   3675.60009765625  3763.199951171875             3670.0
# 5599  2025-02-25  3629.550048828125             3658.0            3621.25
#
#                    Open   Volume
# 5595  3872.199951171875  4366672
# 5596             3761.5  2888572
# 5597   3776.10009765625  1833931
# 5598   3743.14990234375  2508516
# 5599             3625.0  4101954

# %%
#information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   5600 non-null   object
#  1   Close   5599 non-null   object
#  2   High    5599 non-null   object
#  3   Low     5599 non-null   object
#  4   Open    5599 non-null   object
#  5   Volume  5599 non-null   object
# dtypes: object(6)
# memory usage: 262.6+ KB

# %%
df=df.reset_index()

# %%
df.isna().sum()
# Out:
# index     0
# Price     0
# Close     1
# High      1
# Low       1
# Open      1
# Volume    1
# dtype: int64

# %%
df
# Out:
#       index       Price               Close                High  \
# 0         0      Ticker              TCS.NS              TCS.NS
# 1         1        Date                 NaN                 NaN
# 2         2  2002-08-12   28.11940574645996  28.331894414178297
# 3         3  2002-08-13  27.738685607910156  28.606351223804324
# 4         4  2002-08-14  25.826297760009766  27.800675890570268
# ...     ...         ...                 ...                 ...
# 5595   5595  2025-02-19    3784.10009765625   3874.949951171875
# 5596   5596  2025-02-20    3779.39990234375              3788.0
# 5597   5597  2025-02-21              3786.0              3817.0
# 5598   5598  2025-02-24    3675.60009765625   3763.199951171875
# 5599   5599  2025-02-25   3629.550048828125              3658.0
#
#                      Low                Open   Volume
# 0                 TCS.NS              TCS.NS   TCS.NS
# 1                    NaN                 NaN      NaN
# 2     27.428814198950363  27.428814198950363   212976
# 3     27.535051261351068  28.154811257587266   153576
# 4      25.30392621070466  27.800675890570268   822776
# ...                  ...                 ...      ...
# 5595    3768.14990234375   3872.199951171875  4366672
# 5596   3751.300048828125              3761.5  2888572
# 5597              3775.0    3776.10009765625  1833931
# 5598              3670.0    3743.14990234375  2508516
# 5599             3621.25              3625.0  4101954
#
# [5600 rows x 7 columns]

# %%
df = df.drop(['index','Price'],axis = 1)

# %%
df
# Out:
#                    Close                High                 Low  \
# 0                 TCS.NS              TCS.NS              TCS.NS
# 1                    NaN                 NaN                 NaN
# 2      28.11940574645996  28.331894414178297  27.428814198950363
# 3     27.738685607910156  28.606351223804324  27.535051261351068
# 4     25.826297760009766  27.800675890570268   25.30392621070466
# ...                  ...                 ...                 ...
# 5595    3784.10009765625   3874.949951171875    3768.14990234375
# 5596    3779.39990234375              3788.0   3751.300048828125
# 5597              3786.0              3817.0              3775.0
# 5598    3675.60009765625   3763.199951171875              3670.0
# 5599   3629.550048828125              3658.0             3621.25
#
#                     Open   Volume
# 0                 TCS.NS   TCS.NS
# 1                    NaN      NaN
# 2     27.428814198950363   212976
# 3     28.154811257587266   153576
# 4     27.800675890570268   822776
# ...                  ...      ...
# 5595   3872.199951171875  4366672
# 5596              3761.5  2888572
# 5597    3776.10009765625  1833931
# 5598    3743.14990234375  2508516
# 5599              3625.0  4101954
#
# [5600 rows x 5 columns]

# %%
df.head()
# Out:
#                 Close                High                 Low  \
# 0              TCS.NS              TCS.NS              TCS.NS
# 1                 NaN                 NaN                 NaN
# 2   28.11940574645996  28.331894414178297  27.428814198950363
# 3  27.738685607910156  28.606351223804324  27.535051261351068
# 4  25.826297760009766  27.800675890570268   25.30392621070466
#
#                  Open  Volume
# 0              TCS.NS  TCS.NS
# 1                 NaN     NaN
# 2  27.428814198950363  212976
# 3  28.154811257587266  153576
# 4  27.800675890570268  822776

# %%
df.tail()
# Out:
#                   Close               High                Low  \
# 5595   3784.10009765625  3874.949951171875   3768.14990234375
# 5596   3779.39990234375             3788.0  3751.300048828125
# 5597             3786.0             3817.0             3775.0
# 5598   3675.60009765625  3763.199951171875             3670.0
# 5599  3629.550048828125             3658.0            3621.25
#
#                    Open   Volume
# 5595  3872.199951171875  4366672
# 5596             3761.5  2888572
# 5597   3776.10009765625  1833931
# 5598   3743.14990234375  2508516
# 5599             3625.0  4101954

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   5599 non-null   object
#  1   High    5599 non-null   object
#  2   Low     5599 non-null   object
#  3   Open    5599 non-null   object
#  4   Volume  5599 non-null   object
# dtypes: object(5)
# memory usage: 218.9+ KB

# %%
# Clean the data 
#Remove '$' and commas if present
df = df.replace('[\$,]', '', regex=True)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\Shivam Shere\AppData\Local\Temp\ipykernel_4744\1775163916.py:3: SyntaxWarning: invalid escape sequence '\$'
#   df = df.replace('[\$,]', '', regex=True)

# %%
# Convert all columns to numeric (float64)
df = df.apply(pd.to_numeric, errors='coerce')

# %%
# Handle NaN values 
df = df.fillna(0)  # Fill NaN values with 0

# %%
# Convert all columns to float64
df = df.astype('float64')

# %%
df
# Out:
#             Close         High          Low         Open     Volume
# 0        0.000000     0.000000     0.000000     0.000000        0.0
# 1        0.000000     0.000000     0.000000     0.000000        0.0
# 2       28.119406    28.331894    27.428814    27.428814   212976.0
# 3       27.738686    28.606351    27.535051    28.154811   153576.0
# 4       25.826298    27.800676    25.303926    27.800676   822776.0
# ...           ...          ...          ...          ...        ...
# 5595  3784.100098  3874.949951  3768.149902  3872.199951  4366672.0
# 5596  3779.399902  3788.000000  3751.300049  3761.500000  2888572.0
# 5597  3786.000000  3817.000000  3775.000000  3776.100098  1833931.0
# 5598  3675.600098  3763.199951  3670.000000  3743.149902  2508516.0
# 5599  3629.550049  3658.000000  3621.250000  3625.000000  4101954.0
#
# [5600 rows x 5 columns]

# %%
df.head()
# Out:
#        Close       High        Low       Open    Volume
# 0   0.000000   0.000000   0.000000   0.000000       0.0
# 1   0.000000   0.000000   0.000000   0.000000       0.0
# 2  28.119406  28.331894  27.428814  27.428814  212976.0
# 3  27.738686  28.606351  27.535051  28.154811  153576.0
# 4  25.826298  27.800676  25.303926  27.800676  822776.0

# %%
df.tail()
# Out:
#             Close         High          Low         Open     Volume
# 5595  3784.100098  3874.949951  3768.149902  3872.199951  4366672.0
# 5596  3779.399902  3788.000000  3751.300049  3761.500000  2888572.0
# 5597  3786.000000  3817.000000  3775.000000  3776.100098  1833931.0
# 5598  3675.600098  3763.199951  3670.000000  3743.149902  2508516.0
# 5599  3629.550049  3658.000000  3621.250000  3625.000000  4101954.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   5600 non-null   float64
#  1   High    5600 non-null   float64
#  2   Low     5600 non-null   float64
#  3   Open    5600 non-null   float64
#  4   Volume  5600 non-null   float64
# dtypes: float64(5)
# memory usage: 218.9 KB

# %%
df = pd.DataFrame(df)

# Save the clean data DataFrame to a CSV file
df.to_csv('TCS.NS_clean data.csv', index=False)

# %%
# Data Loading
df = pd.read_csv('TCS.NS_clean data.csv')
df
# Out:
#             Close         High          Low         Open     Volume
# 0        0.000000     0.000000     0.000000     0.000000        0.0
# 1        0.000000     0.000000     0.000000     0.000000        0.0
# 2       28.119406    28.331894    27.428814    27.428814   212976.0
# 3       27.738686    28.606351    27.535051    28.154811   153576.0
# 4       25.826298    27.800676    25.303926    27.800676   822776.0
# ...           ...          ...          ...          ...        ...
# 5595  3784.100098  3874.949951  3768.149902  3872.199951  4366672.0
# 5596  3779.399902  3788.000000  3751.300049  3761.500000  2888572.0
# 5597  3786.000000  3817.000000  3775.000000  3776.100098  1833931.0
# 5598  3675.600098  3763.199951  3670.000000  3743.149902  2508516.0
# 5599  3629.550049  3658.000000  3621.250000  3625.000000  4101954.0
#
# [5600 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
df.shape
# Out:
# (5600, 5)

# %%
plt.plot(df.Close)
plt.figure(figsize=(15, 5))

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 5595    4105.052732
# 5596    4100.933743
# 5597    4096.690261
# 5598    4091.884309
# 5599    4086.426382
# Name: Close, Length: 5600, dtype: float64

# %%
# Plot the data
plt.figure(figsize=(15, 5))
plt.plot(df['Close'], label='Close Price', color='blue')
plt.plot(ma100, label='100-Day Moving Average', color='red')  # Solid line (default)
plt.title('Stock Price with 100-Day Moving Average')

plt.legend()
plt.grid()
plt.show()

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 5595    4082.209983
# 5596    4081.757950
# 5597    4081.348646
# 5598    4080.468794
# 5599    4079.681099
# Name: Close, Length: 5600, dtype: float64

# %%
# Plot the data
plt.figure(figsize=(15, 5))
plt.plot(df['Close'], label='Close Price', color='blue')
plt.plot(ma100, label='100-Day Moving Average', color='red')  
plt.plot(ma200, label='200-Day Moving Average', color='green')  
plt.title('Stock Price with 100-Day & 200-Day Moving Average')

plt.legend()
plt.grid()
plt.show()

# %%
#Splitting data into Training and Testing
data_training = pd.DataFrame( df['Close'] [0:int(len (df) *0.70 ) ] )
data_testing = pd.DataFrame( df['Close'] [int(len(df) *0.70): int(len (df) )])

print(data_training.shape)
print(data_testing.shape)
# Out:
# (3919, 1)
# (1681, 1)

# %%
data_training.head()
# Out:
#        Close
# 0   0.000000
# 1   0.000000
# 2  28.119406
# 3  27.738686
# 4  25.826298

# %%
data_training.tail()
# Out:
#             Close
# 3914  1523.645874
# 3915  1523.164429
# 3916  1496.995728
# 3917  1505.857300
# 3918  1526.906006

# %%
data_testing.head()
# Out:
#             Close
# 3919  1510.255127
# 3920  1512.749878
# 3921  1502.509766
# 3922  1523.886475
# 3923  1528.918823

# %%
data_testing.tail()
# Out:
#             Close
# 5595  3784.100098
# 5596  3779.399902
# 5597  3786.000000
# 5598  3675.600098
# 5599  3629.550049

# %%
#Scaling Data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
#fitting Data in MinMaxScaler & Convert into array
data_training_array = scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.        ],
#        [0.        ],
#        [0.01815603],
#        ...,
#        [0.96657467],
#        [0.97229637],
#        [0.98588702]])

# %%
data_training_array.shape
# Out:
# (3919, 1)

# %%
#Divide data into x_train & y_train (Time series analysis anology)
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
#LSTM_Model:

from keras.models import Sequential
from keras.layers import Dense, Dropout,LSTM

model= Sequential()
model.add(LSTM(units=50, activation= 'relu',return_sequences = True,
               input_shape = (x_train.shape[1],1 )))
model.add(Dropout(0.2))

model.add(LSTM(units=60, activation= 'relu',return_sequences = True ))
model.add(Dropout(0.3))

model.add(LSTM(units=80, activation= 'relu',return_sequences = True ))
model.add(Dropout(0.4))


model.add(LSTM(units=120, activation= 'relu' ))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
# Out:
# C:\anaconda101\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100, 50)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100, 60)             │          26,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 100, 60)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 100, 80)             │          45,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 100, 80)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 120)                 │          96,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 120)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             121 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
#Train the model
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 16s 93ms/step - loss: 0.0464
# Epoch 2/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 92ms/step - loss: 0.0046
# Epoch 3/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 91ms/step - loss: 0.0046
# Epoch 4/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 94ms/step - loss: 0.0036
# Epoch 5/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 90ms/step - loss: 0.0036
# Epoch 6/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 93ms/step - loss: 0.0029
# Epoch 7/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 93ms/step - loss: 0.0033
# Epoch 8/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - loss: 0.0033
# Epoch 9/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - loss: 0.0029
# Epoch 10/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 99ms/step - loss: 0.0027
# Epoch 11/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 101ms/step - loss: 0.0026
# Epoch 12/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 98ms/step - loss: 0.0022
# Epoch 13/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 103ms/step - loss: 0.0024
# Epoch 14/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 105ms/step - loss: 0.0024
# Epoch 15/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 103ms/step - loss: 0.0025
# Epoch 16/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 0.0021
# Epoch 17/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 106ms/step - loss: 0.0024
# Epoch 18/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 105ms/step - loss: 0.0021
# Epoch 19/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 106ms/step - loss: 0.0020
# Epoch 20/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 108ms/step - loss: 0.0020
# Epoch 21/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 14s 114ms/step - loss: 0.0022
# Epoch 22/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 111ms/step - loss: 0.0019
# Epoch 23/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 14s 113ms/step - loss: 0.0020
# Epoch 24/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 106ms/step - loss: 0.0019
# Epoch 25/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 101ms/step - loss: 0.0020
# Epoch 26/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - loss: 0.0019
# Epoch 27/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - loss: 0.0018
# Epoch 28/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - loss: 0.0017
# Epoch 29/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - loss: 0.0022
# Epoch 30/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - loss: 0.0017
# Epoch 31/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 98ms/step - loss: 0.0019
# Epoch 32/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 100ms/step - loss: 0.0017
# Epoch 33/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - loss: 0.0020
# Epoch 34/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 101ms/step - loss: 0.0020
# Epoch 35/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 98ms/step - loss: 0.0018
# Epoch 36/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 101ms/step - loss: 0.0018
# Epoch 37/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - loss: 0.0018
# Epoch 38/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 105ms/step - loss: 0.0019
# Epoch 39/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 98ms/step - loss: 0.0018
# Epoch 40/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 99ms/step - loss: 0.0019
# Epoch 41/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - loss: 0.0018
# Epoch 42/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 102ms/step - loss: 0.0019
# Epoch 43/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 0.0020
# Epoch 44/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 102ms/step - loss: 0.0017
# Epoch 45/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 108ms/step - loss: 0.0018
# Epoch 46/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - loss: 0.0018
# Epoch 47/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 101ms/step - loss: 0.0019
# Epoch 48/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 102ms/step - loss: 0.0019
# Epoch 49/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 19s 160ms/step - loss: 0.0018
# Epoch 50/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 33s 278ms/step - loss: 0.0018

# %%
# Save the model
from keras.models import save_model

save_model(model, 'LSTM_model.keras')

# %%
data_training.tail(100)
# Out:
#             Close
# 3819  1137.287964
# 3820  1144.363037
# 3821  1113.624878
# 3822  1108.313232
# 3823  1123.508179
# ...           ...
# 3914  1519.535767
# 3915  1519.055908
# 3916  1492.958252
# 3917  1501.795166
# 3918  1522.787354
#
# [100 rows x 1 columns]

# %%
data_testing.head()
# Out:
#             Close
# 3919  1506.181763
# 3920  1508.668945
# 3921  1498.457031
# 3922  1519.775757
# 3923  1524.794556

# %%
past_100_days = data_training.tail(100)

# %%
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
final_df.head()
# Out:
#          Close
# 0  1137.287964
# 1  1144.363037
# 2  1113.624878
# 3  1108.313232
# 4  1123.508179

# %%
input_data= scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.00861554],
#        [0.01071929],
#        [0.0015794 ],
#        ...,
#        [0.79620147],
#        [0.76337442],
#        [0.74968158]])

# %%
input_data.shape
# Out:
# (1781, 1)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100: i])
    y_test.append(input_data[i, 0])

# %%
x_test , y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1681, 100, 1)
# (1681,)

# %%
#Make Predictions
y_predicted = model.predict(x_test)
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step

# %%
y_predicted
# Out:
# array([[0.13141333],
#        [0.13389598],
#        [0.13630384],
#        ...,
#        [0.7722267 ],
#        [0.7661834 ],
#        [0.75973237]], dtype=float32)

# %%
y_predicted.shape
# Out:
# (1681, 1)

# %%
# Reshape y_predicted and y_test to 2D arrays
y_predicted_reshaped = y_predicted.reshape(-1, 1)
y_test_reshaped = y_test.reshape(-1, 1)

# %%
# Inverse transform the predictions and actual values
inv_predictions = scaler.inverse_transform(y_predicted_reshaped)
inv_y_test = scaler.inverse_transform(y_test_reshaped)

# %%
print("Inverse Transformed Predictions:", inv_predictions[:5])
# Out:
# Inverse Transformed Predictions: [[1550.2664]
#  [1558.6157]
#  [1566.7135]
#  [1574.4941]
#  [1581.9258]]

# %%
print("Inverse Transformed y_test:", inv_y_test[:5])
# Out:
# Inverse Transformed y_test: [[1506.1817627 ]
#  [1508.66894531]
#  [1498.45703125]
#  [1519.77575684]
#  [1524.79455566]]

# %%
scaler.scale_
# Out:
# array([0.00029735])

# %%
scale_factor = 
y_predicted = y_predicted * scale_factor
y_test = y_test * scale_factor

# %%
# Regression accuracy metrics:
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
print('Accuracy of LSTM model')

# Calculate Mean Absolute Error (MAE):
mae = mean_absolute_error(y_test, y_predicted)
print(f"Mean Absolute Error (MAE): {mae}")

# Calculate Mean Squared Error (MSE):
mse = mean_squared_error(y_test, y_predicted)
print(f"Mean Squared Error (MSE): {mse}")

# Calculate Root Mean Squared Error (RMSE):
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error (RMSE): {rmse}")

# Calculate (R-squared) score  R² :
r2 = r2_score(y_test, y_predicted)
print(f"R-squared (R²) Score: {r2}")
# Out:
# Mean Absolute Error (MAE): 1.2313525712772342e-05
# Mean Squared Error (MSE): 2.374655845633511e-10
# Root Mean Squared Error (RMSE): 1.540991838276086e-05
# R-squared (R²) Score: 0.9551184777079468

# %%
# Plotting the actual vs predicted stock prices
plt.figure(figsize=(15, 5))
plt.plot(inv_y_test, color='blue', label='Actual Stock Price')
plt.plot(inv_predictions, color='red', label='Predicted Stock Price using LSTM')
plt.title('TCS Stock Price Prediction: Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
#plt.grid()
plt.show()
